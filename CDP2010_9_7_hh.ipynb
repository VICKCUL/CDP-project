# %%
import numpy as np
import random
import torch
# import torchvision
import matplotlib.pyplot as plt

def set_device():
  device = "cude" if torch.cuda.is_available() else "cpu"
  if device != "cuda":
    print("WARNING: For this notebook to perform best, "
    "if possible, in the menu under `Runtime` ->"
    "`Change runtime type.` select `GPU`")
  else:
    print("GPU is enable in this notebook")

  return device

# set global varaiables
DEVICE = set_device()
DEVICE
# Out:
# WARNING: For this notebook to perform best, if possible, in the menu under `Runtime` ->`Change runtime type.` select `GPU`
# 'cude'

# %%
# %load_ext autoreload
# %autoreload

import numpy as np
import matplotlib.pyplot as plt
from time import time as tm


# Import functions from github
# !git clone https://github.com/RobertRosenbaum/ConductanceBasedBalance.git
from ConductanceBasedBalance.utils import EIFNetworkCurrentPlusFree, EIFNetworkCondPlusFree, GetBlockErdosRenyi, PoissonProcess
# Out:
# fatal: destination path 'ConductanceBasedBalance' already exists and is not an empty directory.

# %% [markdown]
# ** Review Data Cleaning **

# %%
# import libraries
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
# from google.colab import drive
# drive.mount('/content/drive')
#!ls "Investor CDP 2010_Public Data(9.csv"
#df = pd.read_csv("My Drive/data/Investor CDP 2010_Public Data(9.csv", index_col=0)

# %%
# load data
raw_df = pd.read_csv("./CDP2010.csv", encoding='cp1252')
print(raw_df.shape)

# drop NaNs
df1 = raw_df.dropna() # about half quantity of the rows are useless!
print(df1.shape)
df1.iloc[:,6]
# Out:
# (4835, 7)
# (2884, 7)
# 1                       Stopping of one BFW pump of UB8/9
# 2                 Air fin fan blades replacement with FRP
# 3       Automatic combusion control for DHDS charge he...
# 4                    LP Steam APH for CDU2 charge heaters
# 5       DEA Flow optimization to Fuel Gas Amine Absorp...
#                               ...
# 4817    Through the firm’s multi-year alliance with E+...
# 4820    Development and rollout of online sustainabili...
# 4822    Every year, we introduce energy-saving equipme...
# 4826    Vent gas capture in Canadian heavy oil operations
# 4828                           See answer to question 9.9
# Name: 9.7. Please use the table below to describe your company’s actions to reduce its GHG emissions.\n\n9.7 C1. \n1. Actions - please describe, Length: 2884, dtype: object

# %%
#pip install nltk
nltk.download('all')
# nltk.download('punkt')
# nltk.download('stopwords')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /home/haotian/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_rus is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker_tab is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger_tab is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to /home/haotian/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to /home/haotian/nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to /home/haotian/nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package punkt_tab to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package punkt_tab is already up-to-date!
# [nltk_data]    | Downloading package qc to /home/haotian/nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to /home/haotian/nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package tagsets_json to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package tagsets_json is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     /home/haotian/nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
# create preprocess_text function: to clear out words like a, the, this, that, is, of, etc.
def preprocess_text(text):
    # Tokenize the text
    tokens = word_tokenize(text.lower())
    # Remove stop words
    filtered_tokens = [token for token in tokens if token not in stopwords.words('english')]
    # Lemmatize the tokens
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]
    # Join the tokens back into a string
    processed_text = ' '.join(lemmatized_tokens)
    return processed_text
# apply the function df
# df['reviewText'] = df['reviewText'].apply(preprocess_text)
# df

df1['Text'] = df1.iloc[:,6].apply(preprocess_text)

df1
# Out:
# /tmp/ipykernel_23241/1207540044.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Text'] = df1.iloc[:,6].apply(preprocess_text)
#                        Organisation         Country  Access Primary Expansion  \
# 1      Bharat Petroleum Corporation           India  Public         India 200
# 2      Bharat Petroleum Corporation           India  Public         India 200
# 3      Bharat Petroleum Corporation           India  Public         India 200
# 4      Bharat Petroleum Corporation           India  Public         India 200
# 5      Bharat Petroleum Corporation           India  Public         India 200
# ...                             ...             ...     ...               ...
# 4817       Goldman Sachs Group Inc.             USA  Public          FTSE 600
# 4820  Intercontinental Hotels Group  United Kingdom  Public          FTSE 600
# 4822    Mitsubishi Heavy Industries           Japan  Public         Japan 500
# 4826                     Nexen Inc.          Canada  Public        Canada 200
# 4828              TECO Energy, Inc.             USA  Public           S&P 500
#
#                                    Secondary Expansions Complexity  \
# 1                                  Emerging Markets 800       Long
# 2                                  Emerging Markets 800       Long
# 3                                  Emerging Markets 800       Long
# 4                                  Emerging Markets 800       Long
# 5                                  Emerging Markets 800       Long
# ...                                                 ...        ...
# 4817  FTSE All-World 800; Global 500; S&P 500; FTSE ...       Long
# 4820                         Mayday; FTSE 100; FTSE 350       Long
# 4822                                 FTSE All-World 800       Long
# 4826                      Bonds 180; FTSE All-World 800       Long
# 4828                             Electric Utilities 250       Long
#
#      9.7. Please use the table below to describe your company’s actions to reduce its GHG emissions.\n\n9.7 C1. \n1. Actions - please describe  \
# 1                     Stopping of one BFW pump of UB8/9
# 2               Air fin fan blades replacement with FRP
# 3     Automatic combusion control for DHDS charge he...
# 4                  LP Steam APH for CDU2 charge heaters
# 5     DEA Flow optimization to Fuel Gas Amine Absorp...
# ...                                                 ...
# 4817  Through the firm’s multi-year alliance with E+...
# 4820  Development and rollout of online sustainabili...
# 4822  Every year, we introduce energy-saving equipme...
# 4826  Vent gas capture in Canadian heavy oil operations
# 4828                         See answer to question 9.9
#
#                                                    Text
# 1                           stopping one bfw pump ub8/9
# 2                     air fin fan blade replacement frp
# 3        automatic combusion control dhds charge heater
# 4                       lp steam aph cdu2 charge heater
# 5     dea flow optimization fuel gas amine absorptio...
# ...                                                 ...
# 4817  firm ’ multi-year alliance e+co , not-for-prof...
# 4820  development rollout online sustainability tool...
# 4822  every year , introduce energy-saving equipment...
# 4826      vent gas capture canadian heavy oil operation
# 4828                            see answer question 9.9
#
# [2884 rows x 8 columns]

# %%
# Sample DataFrame
import string
# Remove punctuation from the 'Text' column
df1['Text'] = df1['Text'].str.replace(f"[{string.punctuation}]", "", regex=True)

df1
# Out:
# /tmp/ipykernel_23241/142095254.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Text'] = df1['Text'].str.replace(f"[{string.punctuation}]", "", regex=True)
#                        Organisation         Country  Access Primary Expansion  \
# 1      Bharat Petroleum Corporation           India  Public         India 200
# 2      Bharat Petroleum Corporation           India  Public         India 200
# 3      Bharat Petroleum Corporation           India  Public         India 200
# 4      Bharat Petroleum Corporation           India  Public         India 200
# 5      Bharat Petroleum Corporation           India  Public         India 200
# ...                             ...             ...     ...               ...
# 4817       Goldman Sachs Group Inc.             USA  Public          FTSE 600
# 4820  Intercontinental Hotels Group  United Kingdom  Public          FTSE 600
# 4822    Mitsubishi Heavy Industries           Japan  Public         Japan 500
# 4826                     Nexen Inc.          Canada  Public        Canada 200
# 4828              TECO Energy, Inc.             USA  Public           S&P 500
#
#                                    Secondary Expansions Complexity  \
# 1                                  Emerging Markets 800       Long
# 2                                  Emerging Markets 800       Long
# 3                                  Emerging Markets 800       Long
# 4                                  Emerging Markets 800       Long
# 5                                  Emerging Markets 800       Long
# ...                                                 ...        ...
# 4817  FTSE All-World 800; Global 500; S&P 500; FTSE ...       Long
# 4820                         Mayday; FTSE 100; FTSE 350       Long
# 4822                                 FTSE All-World 800       Long
# 4826                      Bonds 180; FTSE All-World 800       Long
# 4828                             Electric Utilities 250       Long
#
#      9.7. Please use the table below to describe your company’s actions to reduce its GHG emissions.\n\n9.7 C1. \n1. Actions - please describe  \
# 1                     Stopping of one BFW pump of UB8/9
# 2               Air fin fan blades replacement with FRP
# 3     Automatic combusion control for DHDS charge he...
# 4                  LP Steam APH for CDU2 charge heaters
# 5     DEA Flow optimization to Fuel Gas Amine Absorp...
# ...                                                 ...
# 4817  Through the firm’s multi-year alliance with E+...
# 4820  Development and rollout of online sustainabili...
# 4822  Every year, we introduce energy-saving equipme...
# 4826  Vent gas capture in Canadian heavy oil operations
# 4828                         See answer to question 9.9
#
#                                                    Text
# 1                            stopping one bfw pump ub89
# 2                     air fin fan blade replacement frp
# 3        automatic combusion control dhds charge heater
# 4                       lp steam aph cdu2 charge heater
# 5     dea flow optimization fuel gas amine absorptio...
# ...                                                 ...
# 4817  firm ’ multiyear alliance eco  notforprofit in...
# 4820  development rollout online sustainability tool...
# 4822  every year  introduce energysaving equipment p...
# 4826      vent gas capture canadian heavy oil operation
# 4828                             see answer question 99
#
# [2884 rows x 8 columns]

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import pickle

import warnings
warnings.filterwarnings("ignore")

# %%
#creating a new column in the dataframe that stores a boolean value whether that row is a duplicate or not
df1['dup'] = df1.duplicated(subset=None, keep='first')

#checking how many duplicates there were by counding the True and False values in that column
df1['dup'].value_counts() # about 5% of the dataset are duplicates. Let's delete them
df1.head()
# let's write the data into a new dataframe, only keeping the lines where the value for "dup" is False
df1 = df1[df1['dup'] == False]
print(df1.shape)

del df1['dup'] # deleting "dup" column since we don't need ot anymore
df1
# Out:
# (2872, 9)
#                        Organisation         Country  Access Primary Expansion  \
# 1      Bharat Petroleum Corporation           India  Public         India 200
# 2      Bharat Petroleum Corporation           India  Public         India 200
# 3      Bharat Petroleum Corporation           India  Public         India 200
# 4      Bharat Petroleum Corporation           India  Public         India 200
# 5      Bharat Petroleum Corporation           India  Public         India 200
# ...                             ...             ...     ...               ...
# 4817       Goldman Sachs Group Inc.             USA  Public          FTSE 600
# 4820  Intercontinental Hotels Group  United Kingdom  Public          FTSE 600
# 4822    Mitsubishi Heavy Industries           Japan  Public         Japan 500
# 4826                     Nexen Inc.          Canada  Public        Canada 200
# 4828              TECO Energy, Inc.             USA  Public           S&P 500
#
#                                    Secondary Expansions Complexity  \
# 1                                  Emerging Markets 800       Long
# 2                                  Emerging Markets 800       Long
# 3                                  Emerging Markets 800       Long
# 4                                  Emerging Markets 800       Long
# 5                                  Emerging Markets 800       Long
# ...                                                 ...        ...
# 4817  FTSE All-World 800; Global 500; S&P 500; FTSE ...       Long
# 4820                         Mayday; FTSE 100; FTSE 350       Long
# 4822                                 FTSE All-World 800       Long
# 4826                      Bonds 180; FTSE All-World 800       Long
# 4828                             Electric Utilities 250       Long
#
#      9.7. Please use the table below to describe your company’s actions to reduce its GHG emissions.\n\n9.7 C1. \n1. Actions - please describe  \
# 1                     Stopping of one BFW pump of UB8/9
# 2               Air fin fan blades replacement with FRP
# 3     Automatic combusion control for DHDS charge he...
# 4                  LP Steam APH for CDU2 charge heaters
# 5     DEA Flow optimization to Fuel Gas Amine Absorp...
# ...                                                 ...
# 4817  Through the firm’s multi-year alliance with E+...
# 4820  Development and rollout of online sustainabili...
# 4822  Every year, we introduce energy-saving equipme...
# 4826  Vent gas capture in Canadian heavy oil operations
# 4828                         See answer to question 9.9
#
#                                                    Text
# 1                            stopping one bfw pump ub89
# 2                     air fin fan blade replacement frp
# 3        automatic combusion control dhds charge heater
# 4                       lp steam aph cdu2 charge heater
# 5     dea flow optimization fuel gas amine absorptio...
# ...                                                 ...
# 4817  firm ’ multiyear alliance eco  notforprofit in...
# 4820  development rollout online sustainability tool...
# 4822  every year  introduce energysaving equipment p...
# 4826      vent gas capture canadian heavy oil operation
# 4828                             see answer question 99
#
# [2872 rows x 8 columns]

# %%
# Data Explainary Analysis

first_10 = df1['Country'].value_counts()[:10]
print(first_10.mean()) #mean incidents per year of 10 biggest countries

print(first_10.std())
#standard deviation
# Out:
# 231.4
# 200.79796369042748

# %%
df1['Country'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Country'>

# %%
#top 5
print(df1['Country'].value_counts()[:10])
sum(df1['Country'].value_counts()[:10])
# Out:
# Country
# USA               685
# United Kingdom    519
# South Africa      202
# Canada            148
# Australia         144
# Germany           140
# France            123
# Spain             123
# Japan             115
# South Korea       115
# Name: count, dtype: int64
# 2314

# %% [markdown]
# ** Text Count**

# %%
from collections import Counter

split_it = df1["Text"][4817].split()
print(split_it)
# Pass the split_it list to instance of Counter class.
Counter = Counter(split_it)

# most_common() produces k frequently encountered
# input values and their respective counts.
most_occur = Counter.most_common(5)

print(most_occur)
# Out:
# ['firm', '’', 'multiyear', 'alliance', 'eco', 'notforprofit', 'invests', 'clean', 'energy', 'business', 'developing', 'country', 'entered', 'transaction', 'purchase', '50000', 'gold', 'standard', 'verified', 'emission', 'reduction', 'vers', 'vers', 'generated', 'manufacture', 'energyefficient', 'cooking', 'stove', 'local', 'artisan', 'manufacturer', 'toyola', 'ghana', 'katene', 'mali', 'stove', '40', 'percent', 'efficient', 'traditional', 'stove', 'used', 'region', 'greatly', 'reduces', 'amount', 'charcoal', 'necessary', 'cook', 'turn', 'reduces', 'carbon', 'dioxide', 'emission', 'deforestation', 'improves', 'indoor', 'air', 'quality', 'provides', 'saving', 'family', 'fuel', 'expense', 'carbon', 'credit', 'local', 'manufacturer', 'expect', 'expand', 'business', 'thereby', 'increasing', 'direct', 'indirect', 'job', 'helping', 'promote', 'sustainable', 'economic', 'development', 'region']
# [('stove', 3), ('business', 2), ('emission', 2), ('vers', 2), ('local', 2)]

# %%
for i in range(len(df1["Text"])):
  split_it = df1["Text"].iloc[i].split()
  df1['Counter'] = Counter(split_it[0])
  # Counter(df1["Text"][4817].split())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 for i in range(len(df1["Text"])):
#       2   split_it = df1["Text"].iloc[i].split()
# ----> 3   df1['Counter'] = Counter(split_it[0])
#       4   # Counter(df1["Text"][4817].split())
#
# TypeError: 'Counter' object is not callable

# %%
for i in range(len(df1["Text"])):
  words = wordcloud.process_text(df1["Text"][i])
  sorted_words = sorted(words.items(), key=lambda x: x[1])
  sorted_words.reverse()
  print(sorted_words[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 for i in range(len(df1["Text"])):
# ----> 2   words = wordcloud.process_text(df1["Text"][i])
#       3   sorted_words = sorted(words.items(), key=lambda x: x[1])
#       4   sorted_words.reverse()
#
# NameError: name 'wordcloud' is not defined

# %% [markdown]
# ** WordCloud**

# %%
# pip install wordcloud

# %%
# Python program to generate WordCloud

# importing all necessary modules
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# df = pd.read_csv("/content/drive/MyDrive/CDP Project/Data/CDP2010.csv", encoding='latin-1')

comment_words = ''
stopwords = set(STOPWORDS)

# iterate through the csv file
# for val in df["Country"]:
for val in df1["Text"]:

	# typecaste each val to string
	val = str(val)

	# split the value
	tokens = val.split()

	# Converts each token into lowercase
	for i in range(len(tokens)):
		tokens[i] = tokens[i].lower()

	comment_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 800, height = 800,
				background_color ='white',
				stopwords = stopwords,
				min_font_size = 10).generate(comment_words)

# plot the WordCloud image
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()
print(wordcloud.words_)
# Out:
# {'new': 1.0, 'project': 0.9747899159663865, 'energy efficiency': 0.9607843137254902, 'reduction': 0.9047619047619048, 'use': 0.9047619047619048, 'system': 0.8543417366946778, 'energy': 0.8375350140056023, 'reduce': 0.7338935574229691, 'technology': 0.6946778711484594, 'building': 0.6778711484593838, 'plant': 0.6246498599439776, 'facility': 0.5910364145658263, 'equipment': 0.5630252100840336, 'program': 0.5462184873949579, 'lighting': 0.5266106442577031, 'operation': 0.5238095238095238, 'electricity': 0.5126050420168067, 'site': 0.4957983193277311, 'installation': 0.47058823529411764, 'company': 0.4481792717086835, 'energy efficient': 0.43137254901960786, 'emission': 0.4257703081232493, 'unit': 0.42016806722689076, 'office': 0.4173669467787115, 'vehicle': 0.41456582633053224, 'energy consumption': 0.40336134453781514, 'improvement': 0.38935574229691877, 'fuel': 0.3753501400560224, 'process': 0.3753501400560224, 'using': 0.37254901960784315, 'initiative': 0.36694677871148457, 'fleet': 0.35294117647058826, 'energy saving': 0.35014005602240894, 'renewable energy': 0.35014005602240894, 'control': 0.3473389355742297, 'reduced': 0.3473389355742297, 'used': 0.3473389355742297, 'store': 0.3473389355742297, 'employee': 0.3389355742296919, 'reducing': 0.33613445378151263, 'saving': 0.3277310924369748, 'water': 0.3165266106442577, 'include': 0.3165266106442577, 'programme': 0.31092436974789917, 'replacement': 0.3081232492997199, 'gas': 0.3025210084033613, 'power': 0.3025210084033613, 'installed': 0.3025210084033613, 'one': 0.29411764705882354, 'air': 0.29411764705882354, 'co2 emission': 0.29411764705882354, 'group': 0.2913165266106443, 'cost': 0.2913165266106443, 'year': 0.2857142857142857, 'u': 0.2857142857142857, 'investment': 0.2801120448179272, 'business': 0.2773109243697479, 'environmental': 0.2773109243697479, 'production': 0.27450980392156865, 'waste': 0.27170868347338933, 'plan': 0.27170868347338933, 'total': 0.2689075630252101, 'product': 0.2661064425770308, 'increase': 0.2661064425770308, 'natural gas': 0.26330532212885155, 'uk': 0.2605042016806723, 'boiler': 0.2549019607843137, 'target': 0.2549019607843137, 'measure': 0.24929971988795518, 'result': 0.24649859943977592, 'including': 0.23249299719887956, 'customer': 0.23249299719887956, 'service': 0.226890756302521, 'energy use': 0.226890756302521, 'network': 0.22408963585434175, 's': 0.22408963585434175, 'number': 0.22408963585434175, 'generation': 0.22128851540616246, 'across': 0.22128851540616246, 'part': 0.2184873949579832, 'work': 0.2184873949579832, 'travel': 0.2184873949579832, 'development': 0.21288515406162464, 'carbon emission': 0.21288515406162464, 'example': 0.20728291316526612, 'standard': 0.20728291316526612, 'emission reduction': 0.20728291316526612, 'implemented': 0.20448179271708683, 'change': 0.20168067226890757, 'less': 0.20168067226890757, 'green': 0.20168067226890757, 'consumption': 0.19887955182072828, 'provide': 0.19887955182072828, 'upgrade': 0.19607843137254902, 'implementation': 0.19607843137254902, 'branch': 0.19327731092436976, 'first': 0.19327731092436976, 'activity': 0.19047619047619047, 'well': 0.19047619047619047, 'efficiency project': 0.19047619047619047, 'air conditioning': 0.19047619047619047, 'optimization': 0.1876750700280112, 'performance': 0.1876750700280112, 'light': 0.18487394957983194, 'location': 0.18487394957983194, 'hour': 0.18487394957983194, 'efficient': 0.18487394957983194, 'etc': 0.18487394957983194, 'within': 0.18487394957983194, 'time': 0.18207282913165265, 'main': 0.18207282913165265, 'steam': 0.1792717086834734, 'improve': 0.1792717086834734, 'based': 0.17647058823529413, 'construction': 0.17647058823529413, 'truck': 0.17647058823529413, 'temperature': 0.17366946778711484, 'paper': 0.17086834733893558, 'significant': 0.17086834733893558, 'installing': 0.17086834733893558, 'global': 0.16806722689075632, 'heat': 0.16806722689075632, 'existing': 0.16806722689075632, 'energy management': 0.16806722689075632, 'action': 0.16526610644 ...

# %%
 WordCloud().process_text(df1["Text"][4817])
# Out:
# {'firm': 1,
#  'multiyear': 1,
#  'alliance': 1,
#  'eco': 1,
#  'notforprofit': 1,
#  'invests': 1,
#  'clean': 1,
#  'energy': 1,
#  'business': 2,
#  'developing': 1,
#  'country': 1,
#  'entered': 1,
#  'transaction': 1,
#  'purchase': 1,
#  'gold': 1,
#  'standard': 1,
#  'verified': 1,
#  'emission': 2,
#  'reduction': 1,
#  'vers': 2,
#  'generated': 1,
#  'manufacture': 1,
#  'energyefficient': 1,
#  'cooking': 1,
#  'stove': 3,
#  'local': 2,
#  'artisan': 1,
#  'manufacturer': 2,
#  'toyola': 1,
#  'ghana': 1,
#  'katene': 1,
#  'mali': 1,
#  'percent': 1,
#  'efficient': 1,
#  'traditional': 1,
#  'used': 1,
#  'region': 2,
#  'greatly': 1,
#  'reduces': 2,
#  'amount': 1,
#  'charcoal': 1,
#  'necessary': 1,
#  'cook': 1,
#  'turn': 1,
#  'carbon': 2,
#  'dioxide': 1,
#  'deforestation': 1,
#  'improves': 1,
#  'indoor': 1,
#  'air': 1,
#  'quality': 1,
#  'provides': 1,
#  'saving': 1,
#  'family': 1,
#  'fuel': 1,
#  'expense': 1,
#  'credit': 1,
#  'expect': 1,
#  'expand': 1,
#  'thereby': 1,
#  'increasing': 1,
#  'direct': 1,
#  'indirect': 1,
#  'job': 1,
#  'helping': 1,
#  'promote': 1,
#  'sustainable': 1,
#  'economic': 1,
#  'development': 1}

# %%
words = wordcloud.process_text(df1["Text"][4817])
sorted_words = sorted(words.items(), key=lambda x: x[1])
sorted_words.reverse()
sorted_words[0]
# Out:
# ('stove', 3)

# %%
words = wordcloud.process_text(df1["Text"])      # fix line to obtain frequency of words in all comments
sorted_words = sorted(words.items(), key=lambda x: x[1])
sorted_words.reverse()
sorted_words[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 words = wordcloud.process_text(df1["Text"])      # fix line to obtain frequency of words in all comments
#       2 sorted_words = sorted(words.items(), key=lambda x: x[1])
#       3 sorted_words.reverse()
#
# File ~/.local/lib/python3.10/site-packages/wordcloud/wordcloud.py:585, in WordCloud.process_text(self, text)
#     582 pattern = r"\w[\w']*" if self.min_word_length <= 1 else r"\w[\w']+"
#     583 regexp = self.regexp if self.regexp is not None else pattern
# --> 585 words = re.findall(regexp, text, flags)
#     586 # remove 's
#     587 words = [word[:-2] if word.lower().endswith("'s") else word
#     588          for word in words]
#
# File /usr/lib/python3.10/re.py:240, in findall(pattern, string, flags)
#     232 def findall(pattern, string, flags=0):
#     233     """Return a list of all non-overlapping matches in the string.
#     234
#     235     If one or more capturing groups are present in the pattern, return
#    (...)
#     238
#     239     Empty matches are included in the result."""
# --> 240     return _compile(pattern, flags).findall(string)
#
# TypeError: expected string or bytes-like object

# %% [markdown]
# ** Sentiment Analaysis**

# %%
from collections import Counter
Counter(df1["Complexity"]) # seems like all Access are Public and most of the rows have Long comlexity
# Out:
# Counter({'Long': 2869, 'Short': 3})

# %%
# initialize NLTK sentiment analyzer
analyzer = SentimentIntensityAnalyzer()
# create get_sentiment function
def get_sentiment(text):
    scores = analyzer.polarity_scores(text)
    sentiment = 1 if scores['pos'] > 0 else 0
    return sentiment
# # apply get_sentiment function
# df['sentiment'] = df['reviewText'].apply(get_sentiment)
# df

df1['sentiment'] = df1['Text'].apply(get_sentiment)
df1
# Out:
#                        Organisation         Country  Access Primary Expansion  \
# 1      Bharat Petroleum Corporation           India  Public         India 200
# 2      Bharat Petroleum Corporation           India  Public         India 200
# 3      Bharat Petroleum Corporation           India  Public         India 200
# 4      Bharat Petroleum Corporation           India  Public         India 200
# 5      Bharat Petroleum Corporation           India  Public         India 200
# ...                             ...             ...     ...               ...
# 4817       Goldman Sachs Group Inc.             USA  Public          FTSE 600
# 4820  Intercontinental Hotels Group  United Kingdom  Public          FTSE 600
# 4822    Mitsubishi Heavy Industries           Japan  Public         Japan 500
# 4826                     Nexen Inc.          Canada  Public        Canada 200
# 4828              TECO Energy, Inc.             USA  Public           S&P 500
#
#                                    Secondary Expansions Complexity  \
# 1                                  Emerging Markets 800       Long
# 2                                  Emerging Markets 800       Long
# 3                                  Emerging Markets 800       Long
# 4                                  Emerging Markets 800       Long
# 5                                  Emerging Markets 800       Long
# ...                                                 ...        ...
# 4817  FTSE All-World 800; Global 500; S&P 500; FTSE ...       Long
# 4820                         Mayday; FTSE 100; FTSE 350       Long
# 4822                                 FTSE All-World 800       Long
# 4826                      Bonds 180; FTSE All-World 800       Long
# 4828                             Electric Utilities 250       Long
#
#      9.7. Please use the table below to describe your company’s actions to reduce its GHG emissions.\n\n9.7 C1. \n1. Actions - please describe  \
# 1                     Stopping of one BFW pump of UB8/9
# 2               Air fin fan blades replacement with FRP
# 3     Automatic combusion control for DHDS charge he...
# 4                  LP Steam APH for CDU2 charge heaters
# 5     DEA Flow optimization to Fuel Gas Amine Absorp...
# ...                                                 ...
# 4817  Through the firm’s multi-year alliance with E+...
# 4820  Development and rollout of online sustainabili...
# 4822  Every year, we introduce energy-saving equipme...
# 4826  Vent gas capture in Canadian heavy oil operations
# 4828                         See answer to question 9.9
#
#                                                    Text  sentiment
# 1                            stopping one bfw pump ub89          0
# 2                     air fin fan blade replacement frp          1
# 3        automatic combusion control dhds charge heater          0
# 4                       lp steam aph cdu2 charge heater          0
# 5     dea flow optimization fuel gas amine absorptio...          1
# ...                                                 ...        ...
# 4817  firm ’ multiyear alliance eco  notforprofit in...          1
# 4820  development rollout online sustainability tool...          1
# 4822  every year  introduce energysaving equipment p...          1
# 4826      vent gas capture canadian heavy oil operation          0
# 4828                             see answer question 99          0
#
# [2872 rows x 9 columns]

# %%
df1["pos"] = 0
for i in range(len(df1["Country"])):
  if df1["Country"].iloc[i] == "USA":
  # print(i)
    df1["pos"].iloc[i] = 1

# df1['Country'].value_counts()[:10]
df1
# Out:
#                        Organisation         Country  Access Primary Expansion  \
# 1      Bharat Petroleum Corporation           India  Public         India 200
# 2      Bharat Petroleum Corporation           India  Public         India 200
# 3      Bharat Petroleum Corporation           India  Public         India 200
# 4      Bharat Petroleum Corporation           India  Public         India 200
# 5      Bharat Petroleum Corporation           India  Public         India 200
# ...                             ...             ...     ...               ...
# 4817       Goldman Sachs Group Inc.             USA  Public          FTSE 600
# 4820  Intercontinental Hotels Group  United Kingdom  Public          FTSE 600
# 4822    Mitsubishi Heavy Industries           Japan  Public         Japan 500
# 4826                     Nexen Inc.          Canada  Public        Canada 200
# 4828              TECO Energy, Inc.             USA  Public           S&P 500
#
#                                    Secondary Expansions Complexity  \
# 1                                  Emerging Markets 800       Long
# 2                                  Emerging Markets 800       Long
# 3                                  Emerging Markets 800       Long
# 4                                  Emerging Markets 800       Long
# 5                                  Emerging Markets 800       Long
# ...                                                 ...        ...
# 4817  FTSE All-World 800; Global 500; S&P 500; FTSE ...       Long
# 4820                         Mayday; FTSE 100; FTSE 350       Long
# 4822                                 FTSE All-World 800       Long
# 4826                      Bonds 180; FTSE All-World 800       Long
# 4828                             Electric Utilities 250       Long
#
#      9.7. Please use the table below to describe your company’s actions to reduce its GHG emissions.\n\n9.7 C1. \n1. Actions - please describe  \
# 1                     Stopping of one BFW pump of UB8/9
# 2               Air fin fan blades replacement with FRP
# 3     Automatic combusion control for DHDS charge he...
# 4                  LP Steam APH for CDU2 charge heaters
# 5     DEA Flow optimization to Fuel Gas Amine Absorp...
# ...                                                 ...
# 4817  Through the firm’s multi-year alliance with E+...
# 4820  Development and rollout of online sustainabili...
# 4822  Every year, we introduce energy-saving equipme...
# 4826  Vent gas capture in Canadian heavy oil operations
# 4828                         See answer to question 9.9
#
#                                                    Text  sentiment  pos
# 1                            stopping one bfw pump ub89          0    0
# 2                     air fin fan blade replacement frp          1    0
# 3        automatic combusion control dhds charge heater          0    0
# 4                       lp steam aph cdu2 charge heater          0    0
# 5     dea flow optimization fuel gas amine absorptio...          1    0
# ...                                                 ...        ...  ...
# 4817  firm ’ multiyear alliance eco  notforprofit in...          1    1
# 4820  development rollout online sustainability tool...          1    0
# 4822  every year  introduce energysaving equipment p...          1    0
# 4826      vent gas capture canadian heavy oil operation          0    0
# 4828                             see answer question 99          0    1
#
# [2872 rows x 10 columns]

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(df1['pos'], df1['sentiment']))
# Out:
# [[ 803 1384]
#  [ 267  418]]

# %%
df1.keys()
# Out:
# Index(['Organisation', 'Country', 'Access', 'Primary Expansion',
#        'Secondary Expansions', 'Complexity',
#        '9.7. Please use the table below to describe your company’s actions to reduce its GHG emissions.\n\n9.7 C1. \n1. Actions - please describe',
#        'Text', 'sentiment', 'pos'],
#       dtype='object')

# %%
# from pathlib import Path
# filepath = Path('/content/drive/MyDrive/CDP Project/Data')
# filepath.parent.mkdir(parents=True, exist_ok=True)
# df1.to_csv('df1.csv', index=False)

# drive.mount('/content/drive')

# df1.to_csv('/content/drive/MyDrive/CDP Project/Data/df1.csv', index=False)

# # Clear punctutation

# %%
from sklearn import tree
X=df1[["Country","Access","Primary Expansion","Complexity"]]
Y=df1['sentiment']

# %%
from sklearn.preprocessing import OneHotEncoder
X_encode=pd.DataFrame()
for col in X.keys():
    feature_reshaped=pd.DataFrame(X,columns=[col])
    onehot_encoder = OneHotEncoder(sparse_output=False, drop='first')  
    onehot_encoded = onehot_encoder.fit_transform(feature_reshaped)
   
    X_encode=pd.concat([X_encode, pd.DataFrame(onehot_encoded, columns=onehot_encoder.get_feature_names_out([col]))], axis=1)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_encode, Y)

# %%
tree.plot_tree(clf,max_depth=2)
# Out:
# [Text(0.5555555555555556, 0.875, 'x[18] <= 0.5\ngini = 0.468\nsamples = 2872\nvalue = [1070, 1802]'),
#  Text(0.3333333333333333, 0.625, 'x[36] <= 0.5\ngini = 0.471\nsamples = 2799\nvalue = [1061, 1738]'),
#  Text(0.4444444444444444, 0.75, 'True  '),
#  Text(0.2222222222222222, 0.375, 'x[39] <= 0.5\ngini = 0.474\nsamples = 2651\nvalue = [1024.0, 1627.0]'),
#  Text(0.1111111111111111, 0.125, '\n  (...)  \n'),
#  Text(0.3333333333333333, 0.125, '\n  (...)  \n'),
#  Text(0.4444444444444444, 0.375, 'gini = 0.375\nsamples = 148\nvalue = [37, 111]'),
#  Text(0.7777777777777778, 0.625, 'x[41] <= 0.5\ngini = 0.216\nsamples = 73\nvalue = [9, 64]'),
#  Text(0.6666666666666667, 0.75, '  False'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.242\nsamples = 64\nvalue = [9, 55]'),
#  Text(0.8888888888888888, 0.375, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]')]

# %%
x_key_list=X_encode.keys()
print(x_key_list[18],x_key_list[4],x_key_list[41],x_key_list[39])
# Out:
# Country_Netherlands Country_Canada Primary Expansion_France 250 Primary Expansion_FTSE 600

# %%
df1.keys()
# Out:
# Index(['Organisation', 'Country', 'Access', 'Primary Expansion',
#        'Secondary Expansions', 'Complexity',
#        '9.7. Please use the table below to describe your company’s actions to reduce its GHG emissions.\n\n9.7 C1. \n1. Actions - please describe',
#        'Text', 'sentiment', 'pos'],
#       dtype='object')

# %%
len(df1)
# Out:
# 2872

# %% [markdown]
# # Bert

# %%
# Load pre-trained BERT model and tokenizer

from transformers import BertModel, BertTokenizer
import torch
from tqdm import tqdm

model_name = "bert-base-uncased"  # You can use other pretrained BERT models as well
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)
df1["CLS_embedding"]=None
df1["MaxPool_embedding"]=None
df1["MeanPool_embedding"]=None
for idx in tqdm(range(len(df1))):
    
    # Input text
    text = df1['9.7. Please use the table below to describe your company’s actions to reduce its GHG emissions.\n\n9.7 C1. \n1. Actions - please describe'].iloc[idx]
   
    # Tokenize the input text and convert to PyTorch tensors
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)
    
    # Get model outputs
    with torch.no_grad():
        outputs = model(**inputs)
    
    # Extract the last hidden state (embeddings)
    last_hidden_state = outputs.last_hidden_state  # Shape: (batch_size, sequence_length, hidden_size)
    
    attention_mask = inputs['attention_mask']
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size())
    sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, dim=1)
    sum_mask = torch.sum(input_mask_expanded, dim=1)
    mean_pooled_embedding = sum_embeddings / sum_mask  # Shape: (batch_size, hidden_size)
    
    # 3. Use max pooling to get a sentence embedding
    max_pooled_embedding, _ = torch.max(last_hidden_state * input_mask_expanded, dim=1)
    
    # Print the embeddings
    # print("CLS Embedding shape:", cls_embedding.shape)
    # print("Mean Pooled Embedding shape:", mean_pooled_embedding.shape)
    # print("Max Pooled Embedding shape:", max_pooled_embedding.shape)
    # df1["CLS_embedding"].iloc[idx]=cls_embedding.detach().numpy()
    df1["MaxPool_embedding"].iloc[idx]=max_pooled_embedding.detach().numpy()
    df1["MeanPool_embedding"].iloc[idx]=mean_pooled_embedding.detach().numpy()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 2872/2872 [01:37<00:00, 29.46it/s]

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
# print(df1["MaxPool_embedding"].iloc[0].shape)
reduced_embeddings = tsne.fit_transform(np.concatenate(df1["MaxPool_embedding"].values))
plt.figure(figsize=(8, 6))
df1['x'] = reduced_embeddings[:, 0]
df1['y'] = reduced_embeddings[:, 1]

# Plot the t-SNE results, colored by 'Country' or 'label'
plt.figure(figsize=(8, 6))
for category in df1["Country"].unique():  # Assuming 'Country' is the label column
    subset = df1[df1["Country"] == category]
    plt.scatter(subset['x'], subset['y'], label=category, alpha=0.3, edgecolors=None)

plt.legend()

# %%
import umap.umap_ as umap

# print(df1["MaxPool_embedding"].iloc[0].shape)

reducer = umap.UMAP(n_components=2, random_state=42)
reduced_embeddings = reducer.fit_transform(np.concatenate(df1["MaxPool_embedding"].values))


plt.figure(figsize=(8, 6))
df1['x'] = reduced_embeddings[:, 0]
df1['y'] = reduced_embeddings[:, 1]

# Plot the t-SNE results, colored by 'Country' or 'label'
plt.figure(figsize=(8, 6))
for category in df1["Country"].unique():  # Assuming 'Country' is the label column
    subset = df1[df1["Country"] == category]
    plt.scatter(subset['x'], subset['y'], label=category, alpha=0.3, edgecolors=None)

plt.legend()

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
# print(df1["MaxPool_embedding"].iloc[0].shape)
reduced_embeddings = tsne.fit_transform(np.concatenate(df1["MeanPool_embedding"].values))
plt.figure(figsize=(8, 6))
df1['x'] = reduced_embeddings[:, 0]
df1['y'] = reduced_embeddings[:, 1]

# Plot the t-SNE results, colored by 'Country' or 'label'
plt.figure(figsize=(8, 6))
for category in df1["Country"].unique():  # Assuming 'Country' is the label column
    subset = df1[df1["Country"] == category]
    plt.scatter(subset['x'], subset['y'], label=category, alpha=0.3, edgecolors=None)

plt.legend()

# %%
import umap.umap_ as umap

# print(df1["MaxPool_embedding"].iloc[0].shape)

reducer = umap.UMAP(n_components=2, random_state=42)
reduced_embeddings = reducer.fit_transform(np.concatenate(df1["MeanPool_embedding"].values))


plt.figure(figsize=(8, 6))
df1['x'] = reduced_embeddings[:, 0]
df1['y'] = reduced_embeddings[:, 1]

# Plot the t-SNE results, colored by 'Country' or 'label'
plt.figure(figsize=(8, 6))
for category in df1["Country"].unique():  # Assuming 'Country' is the label column
    subset = df1[df1["Country"] == category]
    plt.scatter(subset['x'], subset['y'], label=category, alpha=0.3, edgecolors=None)

plt.legend()

# %% [markdown]
# # Berttopic

# %%
from tqdm import tqdm
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer

# Initialize a SentenceTransformer model
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')



df1["SBert_embedding"]=None

for idx in tqdm(range(len(df1))):
    
    # Input text
    text = df1['9.7. Please use the table below to describe your company’s actions to reduce its GHG emissions.\n\n9.7 C1. \n1. Actions - please describe'].iloc[idx]
   
    # Tokenize the input text and convert to PyTorch tensors
    embedding = embedding_model.encode(text)

  
    df1["SBert_embedding"].iloc[idx]=embedding
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2872/2872 [00:12<00:00, 229.14it/s]

# %%
import umap.umap_ as umap

# print(df1["MaxPool_embedding"].iloc[0].shape)

reducer = umap.UMAP(n_components=2, random_state=42)
reduced_embeddings = reducer.fit_transform(np.vstack(df1["SBert_embedding"].values))


plt.figure(figsize=(8, 6))
df1['x'] = reduced_embeddings[:, 0]
df1['y'] = reduced_embeddings[:, 1]

# Plot the t-SNE results, colored by 'Country' or 'label'
plt.figure(figsize=(8, 6))
for category in df1["Country"].unique():  # Assuming 'Country' is the label column
    subset = df1[df1["Country"] == category]
    plt.scatter(subset['x'], subset['y'], label=category, alpha=0.3, edgecolors=None)

plt.legend()

# %%
import umap.umap_ as umap
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # Ensure this is imported correctly

# Perform UMAP reduction to 3D
reducer = umap.UMAP(n_components=3, random_state=42)
reduced_embeddings = reducer.fit_transform(np.vstack(df1["SBert_embedding"].values))

# Add the reduced dimensions to the DataFrame
df1['x'] = reduced_embeddings[:, 0]
df1['y'] = reduced_embeddings[:, 1]
df1['z'] = reduced_embeddings[:, 2]

# Plot the UMAP results in 3D, colored by 'Country' or 'label'
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

for category in df1["Country"].unique():  # Assuming 'Country' is the label column
    subset = df1[df1["Country"] == category]
    ax.scatter(
        subset['x'], subset['y'], subset['z'],
        label=category, alpha=0.7, edgecolors='none'  # Change edgecolors=None to 'none'
    )

ax.set_title("3D UMAP Visualization")
ax.set_xlabel("UMAP-1")
ax.set_ylabel("UMAP-2")
ax.set_zlabel("UMAP-3")
ax.legend()
plt.show()

# %%
import umap.umap_ as umap

# print(df1["MaxPool_embedding"].iloc[0].shape)

reducer = umap.UMAP(n_components=2, random_state=42)
reduced_embeddings = reducer.fit_transform(np.vstack(df1["SBert_embedding"].values))


plt.figure(figsize=(8, 6))
df1['x'] = reduced_embeddings[:, 0]
df1['y'] = reduced_embeddings[:, 1]

# Plot the t-SNE results, colored by 'Country' or 'label'
plt.figure(figsize=(8, 6))


subset = df1[df1["Country"] == "India"]
plt.scatter(subset['x'], subset['y'], label="is india", alpha=0.3, edgecolors=None)

subset = df1[df1["Country"] != "India"]
plt.scatter(subset['x'], subset['y'], label="not india", alpha=0.3, edgecolors=None)



plt.legend()
